# %% [markdown]
# # AICrypto

# %% [markdown]
# # Exploaratory Data Anaylysis
# # Testing Datasets

# %%
from datasets import load_dataset

# Login using e.g. `huggingface-cli login` to access this dataset

enigmata_ds = load_dataset("BytedTsinghua-SIA/Enigmata-Eval")
cipher_ds = load_dataset("yu0226/CipherBank", "Atbash")
dual_average_ds = load_dataset("yu0226/CipherBank", "DualAvgCode")
parity_shit_ds = load_dataset("yu0226/CipherBank", "ParityShift")

# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
##ds["train"].to_csv("BytedTsinghua-SIA/Enigmata-Eval_train.csv")
print(enigmata_ds)
#ds["test"].to_csv("BytedTsinghua-SIA/Enigmata-Eval_test.csv")

print(cipher_ds)
print(dual_average_ds)
print(parity_shit_ds)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['prompt', 'reward_model', 'data_source', 'ability', 'extra_info', 'answer', 'meta', 'task_type', 'task_name'],
#         num_rows: 4758
#     })
# })
# DatasetDict({
#     test: Dataset({
#         features: ['domain', 'sub_domain', 'plaintext', 'Atbash'],
#         num_rows: 262
#     })
# })
# DatasetDict({
#     test: Dataset({
#         features: ['domain', 'sub_domain', 'plaintext', 'DualAvgCode'],
#         num_rows: 262
#     })
# })
# DatasetDict({
#     test: Dataset({
#         features: ['domain', 'sub_domain', 'plaintext', 'ParityShift'],
#         num_rows: 262
#     })
# })
